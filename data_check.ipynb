# %%
print("Hello")
## just for test
# Out:
# Hello

# %% [markdown]
# ### GET&Check data

# %%
import pandas as pd
import numpy as np

sub=pd.read_csv("/home/junseo/Desktop/2023_1st_vacation/KRX_py/KRX_DATA/open/sample_submission.csv")
data=pd.read_csv("/home/junseo/Desktop/2023_1st_vacation/KRX_py/KRX_DATA/open/train.csv")

# %%
sub
# Out:
#          종목코드    순위
# 0     A000020     1
# 1     A000040     2
# 2     A000050     3
# 3     A000070     4
# 4     A000080     5
# ...       ...   ...
# 1995  A375500  1996
# 1996  A378850  1997
# 1997  A383220  1998
# 1998  A383310  1999
# 1999  A383800  2000
#
# [2000 rows x 2 columns]

# %%
data
# Out:
#               일자     종목코드     종목명      거래량     시가     고가     저가     종가
# 0       20210601  A060310      3S   166690   2890   2970   2885   2920
# 1       20210601  A095570  AJ네트웍스    63836   5860   5940   5750   5780
# 2       20210601  A006840   AK홀딩스   103691  35500  35600  34150  34400
# 3       20210601  A054620     APS   462544  14600  14950  13800  14950
# 4       20210601  A265520   AP시스템   131987  29150  29150  28800  29050
# ...          ...      ...     ...      ...    ...    ...    ...    ...
# 987995  20230530  A189980  흥국에프엔비   272284   3005   3035   2955   2980
# 987996  20230530  A000540    흥국화재    50218   3250   3255   3195   3215
# 987997  20230530  A003280    흥아해운   130664   1344   1395   1340   1370
# 987998  20230530  A037440      희림   141932   9170   9260   9170   9200
# 987999  20230530  A238490      힘스  2611843   6410   8220   6300   8220
#
# [988000 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988000 entries, 0 to 987999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   일자      988000 non-null  int64
#  1   종목코드    988000 non-null  object
#  2   종목명     988000 non-null  object
#  3   거래량     988000 non-null  int64
#  4   시가      988000 non-null  int64
#  5   고가      988000 non-null  int64
#  6   저가      988000 non-null  int64
#  7   종가      988000 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 60.3+ MB

# %% [markdown]
# - Data Analisys

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data.head()
# Out:
#          일자     종목코드     종목명     거래량     시가     고가     저가     종가
# 0  20210601  A060310      3S  166690   2890   2970   2885   2920
# 1  20210601  A095570  AJ네트웍스   63836   5860   5940   5750   5780
# 2  20210601  A006840   AK홀딩스  103691  35500  35600  34150  34400
# 3  20210601  A054620     APS  462544  14600  14950  13800  14950
# 4  20210601  A265520   AP시스템  131987  29150  29150  28800  29050

# %%
data["일자"]
# Out:
# 0         20210601
# 1         20210601
# 2         20210601
# 3         20210601
# 4         20210601
#             ...
# 987995    20230530
# 987996    20230530
# 987997    20230530
# 987998    20230530
# 987999    20230530
# Name: 일자, Length: 988000, dtype: int64

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense 
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# [sequence of the work]
# 1. make data index by company
# 2. delete word data
# 3. make AOC label
# (sorted by date)
#
# - to get resonable end price should get 'amount of change'
# - !!!need help!!!
# - slice data and make new index AOC
# - ((datbefore endprice)-endprice)/100

# %%
numbers_data=data.

scaler=MinMaxScaler()
scaler.fit(numbers_data)

data_corr=_numbers_data.corr()
data_corr_sort=data_corr.sort_values("종가",ascending=False)

data_corr["종가"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6597/2675425833.py in ?()
# ----> 2 scaler=MinMaxScaler()
#       3 scaler.fit(data)
#       4
#       5 data_corr=data.corr()
#
# ~/anaconda3/envs/KRX_python/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y)
#     430             Fitted scaler.
#     431         """
#     432         # Reset internal state before fitting
#     433         self._reset()
# --> 434         return self.partial_fit(X, y)
#
# ~/anaconda3/envs/KRX_python/lib/python3.9/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~/anaconda3/envs/KRX_python/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y)
#     468                 "Consider using MaxAbsScaler instead."
#     469             )
#     470
#     471         first_pass = not hasattr(self, "n_samples_seen_")
# --> 472         X = self._validate_data(
#     473             X,
#     474             reset=first_pass,
#     475             dtype=FLOAT_DTYPES,
#
# ~/anaconda3/envs/KRX_python/lib/python3.9/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     600                 out = y
#     601             else:
#     602                 out = X, y
#     603         elif not no_val_X and no_val_y:
# --> 604             out = check_array(X, input_name="X", **check_params)
#     605         elif no_val_X and not no_val_y:
#     606             out = _check_y(y, **check_params)
#     607         else:
#
# ~/anaconda3/envs/KRX_python/lib/python3.9/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915                     array = xp.astype(array, dtype, copy=False)
#     916                 else:
#     917                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     918             except ComplexWarning as complex_warning:
# --> 919                 raise ValueError(
#     920                     "Complex data not supported\n{}\n".format(array)
#     921                 ) from complex_warning
#     922
#
# ~/anaconda3/envs/KRX_python/lib/python3.9/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# ~/anaconda3/envs/KRX_python/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'A060310'

# %% [markdown]
# - Model Guessing end price by using 15 days data before target day
