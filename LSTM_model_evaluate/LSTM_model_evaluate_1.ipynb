# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.preprocessing import MinMaxScaler
import os
from google.colab import drive

def getAOC(data):
  AOC = []
  close = data['종가']

  # aoc = (금일 종가 - 전일 종가) / 전일 종가
  for i in range(len(close)):
    aoc_value = ((close[i] - close[i-1]) / close[i-1]) * 100
    if(i % 494 == 0):
      aoc_value = 0
    AOC.append(aoc_value)

  return AOC

drive.mount('/content/drive')

sub=pd.read_csv("./drive/MyDrive/Colab Notebooks/sample_submission.csv")
data=pd.read_csv("./drive/MyDrive/Colab Notebooks/train.csv")

#sort data by "종목명"
subject_Data=data.sort_values(by="종목명",inplace=False)
subject_Data.head()
subject_Data.columns

pv_s_data=pd.pivot_table(subject_Data,values=['거래량', '시가', '고가', '저가', '종가'],index=['종목코드','일자'])

pv_s_data["AOC"] = getAOC(pv_s_data)

divided = pv_s_data.index.get_level_values('종목코드').unique()

sliced_dataframes = []

for i in divided:
    sliced_data = pv_s_data.loc[i]
    sliced_dataframe = sliced_data.reset_index()
    sliced_dataframes.append(sliced_dataframe)
# Out:
# Mounted at /content/drive

# %%
#MinMaxScaler
scaler = MinMaxScaler()
scale_cols = ['거래량', '고가', '시가', '저가', '종가', 'AOC']
scaled = scaler.fit_transform(sliced_dataframes[200][scale_cols])

# %%
df = pd.DataFrame(scaled, columns=scale_cols)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop('종가', 1), df['종가'], test_size=0.2, random_state=0, shuffle=False)
# Out:
# <ipython-input-4-1202195c6716>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_train, x_test, y_train, y_test = train_test_split(df.drop('종가', 1), df['종가'], test_size=0.2, random_state=0, shuffle=False)

# %%
import tensorflow as tf
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1][-1]))  # 종가만 사용하여 (window, 종가) 형태로 변환
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=20
BATCH_SIZE=32

# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %% [markdown]
# 모델 평가 (Model Evaluate)
#
# - 각 epoch와 layer에 따른 정확도를 비교
# - 어느 지점부터 학습 손실(train_loss)은 줄어들지만, 검증 손실(val_loss)은 늘어난다면 과적합(Overfitting)이 된 것이라고 판단

# %%
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam

def train_and_evaluate(num_epochs, num_layers):
    model = Sequential([
        Conv1D(filters=32, kernel_size=5,
               padding="causal",
               activation="relu",
               input_shape=[WINDOW_SIZE, 1]),
        LSTM(16, activation='tanh'),
        Dense(16, activation="relu"),
        Dense(1),
    ])

    loss = Huber()
    optimizer = Adam(0.0005)
    model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

    earlystopping = EarlyStopping(monitor='val_loss', patience=20)
    filename = os.path.join('tmp', 'ckeckpointer.ckpt')
    checkpoint = ModelCheckpoint(filename,
                                 save_weights_only=True,
                                 save_best_only=True,
                                 monitor='val_loss',
                                 verbose=1)

    history = model.fit(train_data,
                        validation_data=test_data,
                        epochs=num_epochs,
                        callbacks=[checkpoint, earlystopping],
                        verbose=0)

    return history

# %%
epochs_list = [50, 100, 150, 200]  # 변경할 epoch 리스트
layers_list = [1, 2, 3]  # 변경할 LSTM 층 수 리스트

train_loss_dict = {}  # 학습 데이터 손실을 저장할 딕셔너리
val_loss_dict = {}  # 검증 데이터 손실을 저장할 딕셔너리

for num_epochs in epochs_list:
    for num_layers in layers_list:
        print(f"Training for {num_epochs} epochs and {num_layers} layers...")
        history = train_and_evaluate(num_epochs, num_layers)
        key = f"{num_epochs} epochs, {num_layers} layers"

        train_loss_dict[key] = history.history['loss']
        val_loss_dict[key] = history.history['val_loss']
# Out:
# Training for 50 epochs and 1 layers...
#
# Epoch 1: val_loss improved from inf to 0.02662, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.02662 to 0.00355, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.00355 to 0.00194, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss did not improve from 0.00194
#
# Epoch 5: val_loss did not improve from 0.00194
#
# Epoch 6: val_loss improved from 0.00194 to 0.00125, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 7: val_loss did not improve from 0.00125
#
# Epoch 8: val_loss did not improve from 0.00125
#
# Epoch 9: val_loss improved from 0.00125 to 0.00109, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 10: val_loss improved from 0.00109 to 0.00107, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 11: val_loss improved from 0.00107 to 0.00096, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 12: val_loss improved from 0.00096 to 0.00094, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 13: val_loss improved from 0.00094 to 0.00090, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 14: val_loss did not improve from 0.00090
#
# Epoch 15: val_loss improved from 0.00090 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 16: val_loss did not improve from 0.00087
#
# Epoch 17: val_loss improved from 0.00087 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 18: val_loss improved from 0.00087 to 0.00086, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 19: val_loss improved from 0.00086 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 20: val_loss improved from 0.00084 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 21: val_loss did not improve from 0.00084
#
# Epoch 22: val_loss improved from 0.00084 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 23: val_loss improved from 0.00084 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 24: val_loss improved from 0.00081 to 0.00080, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 25: val_loss did not improve from 0.00080
#
# Epoch 26: val_loss improved from 0.00080 to 0.00078, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 27: val_loss improved from 0.00078 to 0.00078, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 28: val_loss did not improve from 0.00078
#
# Epoch 29: val_loss did not improve from 0.00078
#
# Epoch 30: val_loss improved from 0.00078 to 0.00078, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss improved from 0.00078 to 0.00076, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 32: val_loss did not improve from 0.00076
#
# Epoch 33: val_loss improved from 0.00076 to 0.00075, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 34: val_loss improved from 0.00075 to 0.00074, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss did not improve from 0.00074
#
# Epoch 36: val_loss improved from 0.00074 to 0.00074, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 37: val_loss improved from 0.00074 to 0.00073, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 38: val_loss did not improve from 0.00073
#
# Epoch 39: val_loss improved from 0.00073 to 0.00071, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 40: val_loss did not improve from 0.00071
#
# Epoch 41: val_loss improved from 0.00071 to 0.00070, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 42: val_loss did not improve from 0.00070
#
# Epoch 43: val_loss did not improve from 0.00070
#
# Epoch 44: val_loss did not improve from 0.00070
#
# Epoch 45: val_loss did not improve from 0.00070
#
# Epoch 46: val_loss improved from 0.00070 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 47: val_loss did not improve from 0.00068
#
# Epoch 48: val_loss improved from 0.00068 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 49: val_loss improved from 0.00068 to 0.00067, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 50: val_loss did not improve from 0.00067
# Training for 50 epochs and 2 layers...
#
# Epoch 1: val_loss improved from inf to 0.05517, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.05517 to 0.03120, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.03120 to 0.01064, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss improved from 0.01064 to 0.00102, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 5: val_loss did not improve from 0.00102
#
# Epoch 6: val_loss did not improve from 0.00102
#
# Epoch 7: val_loss did not improve from 0.00102
#
# Epoch 8: val_loss did not improve from 0.00102
#
# Epoch 9: val_loss did not improve from 0.00102
#
# Epoch 10: val_loss did not improve from 0.00102
#
# Epoch 11: val_loss did not improve from 0.00102
#
# Epoch 12: val_loss did not improve from 0.00102
#
# Epoch 13: val_loss did not improve from 0.00102
#
# Epoch 14: val_loss did not improve from 0.00102
#
# Epoch 15: val_loss did not improve from 0.00102
#
# Epoch 16: val_loss did not improve from 0.00102
#
# Epoch 17: val_loss did not improve from 0.00102
#
# Epoch 18: val_loss did not improve from 0.00102
#
# Epoch 19: val_loss did not improve from 0.00102
#
# Epoch 20: val_loss did not improve from 0.00102
#
# Epoch 21: val_loss did not improve from 0.00102
#
# Epoch 22: val_loss did not improve from 0.00102
#
# Epoch 23: val_loss did not improve from 0.00102
#
# Epoch 24: val_loss improved from 0.00102 to 0.00100, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 25: val_loss improved from 0.00100 to 0.00100, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 26: val_loss improved from 0.00100 to 0.00099, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 27: val_loss did not improve from 0.00099
#
# Epoch 28: val_loss improved from 0.00099 to 0.00097, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 29: val_loss improved from 0.00097 to 0.00096, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 30: val_loss improved from 0.00096 to 0.00095, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss improved from 0.00095 to 0.00094, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 32: val_loss improved from 0.00094 to 0.00093, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 33: val_loss did not improve from 0.00093
#
# Epoch 34: val_loss improved from 0.00093 to 0.00092, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss did not improve from 0.00092
#
# Epoch 36: val_loss improved from 0.00092 to 0.00090, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 37: val_loss improved from 0.00090 to 0.00089, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 38: val_loss improved from 0.00089 to 0.00089, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 39: val_loss improved from 0.00089 to 0.00088, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 40: val_loss improved from 0.00088 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 41: val_loss improved from 0.00087 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 42: val_loss improved from 0.00087 to 0.00085, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 43: val_loss did not improve from 0.00085
#
# Epoch 44: val_loss did not improve from 0.00085
#
# Epoch 45: val_loss improved from 0.00085 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 46: val_loss improved from 0.00084 to 0.00083, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 47: val_loss improved from 0.00083 to 0.00082, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 48: val_loss did not improve from 0.00082
#
# Epoch 49: val_loss improved from 0.00082 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 50: val_loss improved from 0.00081 to 0.00080, saving model to tmp/ckeckpointer.ckpt
# Training for 50 epochs and 3 layers...
#
# Epoch 1: val_loss improved from inf to 0.05555, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.05555 to 0.03582, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.03582 to 0.02021, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss improved from 0.02021 to 0.00497, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 5: val_loss improved from 0.00497 to 0.00168, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 6: val_loss did not improve from 0.00168
#
# Epoch 7: val_loss did not improve from 0.00168
#
# Epoch 8: val_loss did not improve from 0.00168
#
# Epoch 9: val_loss did not improve from 0.00168
#
# Epoch 10: val_loss improved from 0.00168 to 0.00165, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 11: val_loss improved from 0.00165 to 0.00130, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 12: val_loss improved from 0.00130 to 0.00119, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 13: val_loss improved from 0.00119 to 0.00105, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 14: val_loss did not improve from 0.00105
#
# Epoch 15: val_loss improved from 0.00105 to 0.00102, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 16: val_loss did not improve from 0.00102
#
# Epoch 17: val_loss improved from 0.00102 to 0.00102, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 18: val_loss did not improve from 0.00102
#
# Epoch 19: val_loss improved from 0.00102 to 0.00100, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 20: val_loss improved from 0.00100 to 0.00099, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 21: val_loss did not improve from 0.00099
#
# Epoch 22: val_loss improved from 0.00099 to 0.00099, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 23: val_loss improved from 0.00099 to 0.00097, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 24: val_loss improved from 0.00097 to 0.00095, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 25: val_loss improved from 0.00095 to 0.00095, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 26: val_loss improved from 0.00095 to 0.00094, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 27: val_loss did not improve from 0.00094
#
# Epoch 28: val_loss improved from 0.00094 to 0.00091, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 29: val_loss did not improve from 0.00091
#
# Epoch 30: val_loss improved from 0.00091 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss did not improve from 0.00087
#
# Epoch 32: val_loss did not improve from 0.00087
#
# Epoch 33: val_loss improved from 0.00087 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 34: val_loss improved from 0.00084 to 0.00083, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss improved from 0.00083 to 0.00082, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 36: val_loss improved from 0.00082 to 0.00082, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 37: val_loss improved from 0.00082 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 38: val_loss did not improve from 0.00081
#
# Epoch 39: val_loss did not improve from 0.00081
#
# Epoch 40: val_loss improved from 0.00081 to 0.00080, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 41: val_loss improved from 0.00080 to 0.00078, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 42: val_loss improved from 0.00078 to 0.00077, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 43: val_loss improved from 0.00077 to 0.00077, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 44: val_loss did not improve from 0.00077
#
# Epoch 45: val_loss improved from 0.00077 to 0.00076, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 46: val_loss did not improve from 0.00076
#
# Epoch 47: val_loss improved from 0.00076 to 0.00075, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 48: val_loss improved from 0.00075 to 0.00074, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 49: val_loss did not improve from 0.00074
#
# Epoch 50: val_loss did not improve from 0.00074
# Training for 100 epochs and 1 layers...
#
# Epoch 1: val_loss improved from inf to 0.04861, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.04861 to 0.02411, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.02411 to 0.00522, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss improved from 0.00522 to 0.00340, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 5: val_loss did not improve from 0.00340
#
# Epoch 6: val_loss improved from 0.00340 to 0.00138, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 7: val_loss improved from 0.00138 to 0.00131, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 8: val_loss did not improve from 0.00131
#
# Epoch 9: val_loss did not improve from 0.00131
#
# Epoch 10: val_loss improved from 0.00131 to 0.00114, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 11: val_loss improved from 0.00114 to 0.00111, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 12: val_loss improved from 0.00111 to 0.00107, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 13: val_loss did not improve from 0.00107
#
# Epoch 14: val_loss improved from 0.00107 to 0.00105, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 15: val_loss did not improve from 0.00105
#
# Epoch 16: val_loss improved from 0.00105 to 0.00102, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 17: val_loss did not improve from 0.00102
#
# Epoch 18: val_loss improved from 0.00102 to 0.00100, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 19: val_loss improved from 0.00100 to 0.00099, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 20: val_loss did not improve from 0.00099
#
# Epoch 21: val_loss did not improve from 0.00099
#
# Epoch 22: val_loss did not improve from 0.00099
#
# Epoch 23: val_loss did not improve from 0.00099
#
# Epoch 24: val_loss did not improve from 0.00099
#
# Epoch 25: val_loss improved from 0.00099 to 0.00094, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 26: val_loss did not improve from 0.00094
#
# Epoch 27: val_loss improved from 0.00094 to 0.00092, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 28: val_loss did not improve from 0.00092
#
# Epoch 29: val_loss improved from 0.00092 to 0.00091, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 30: val_loss improved from 0.00091 to 0.00089, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss did not improve from 0.00089
#
# Epoch 32: val_loss improved from 0.00089 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 33: val_loss did not improve from 0.00087
#
# Epoch 34: val_loss improved from 0.00087 to 0.00086, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss did not improve from 0.00086
#
# Epoch 36: val_loss improved from 0.00086 to 0.00083, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 37: val_loss did not improve from 0.00083
#
# Epoch 38: val_loss improved from 0.00083 to 0.00082, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 39: val_loss did not improve from 0.00082
#
# Epoch 40: val_loss improved from 0.00082 to 0.00080, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 41: val_loss did not improve from 0.00080
#
# Epoch 42: val_loss did not improve from 0.00080
#
# Epoch 43: val_loss improved from 0.00080 to 0.00078, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 44: val_loss improved from 0.00078 to 0.00076, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 45: val_loss did not improve from 0.00076
#
# Epoch 46: val_loss did not improve from 0.00076
#
# Epoch 47: val_loss did not improve from 0.00076
#
# Epoch 48: val_loss improved from 0.00076 to 0.00076, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 49: val_loss did not improve from 0.00076
#
# Epoch 50: val_loss improved from 0.00076 to 0.00076, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 51: val_loss improved from 0.00076 to 0.00075, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 52: val_loss improved from 0.00075 to 0.00071, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 53: val_loss improved from 0.00071 to 0.00070, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 54: val_loss did not improve from 0.00070
#
# Epoch 55: val_loss improved from 0.00070 to 0.00069, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 56: val_loss did not improve from 0.00069
#
# Epoch 57: val_loss did not improve from 0.00069
#
# Epoch 58: val_loss did not improve from 0.00069
#
# Epoch 59: val_loss improved from 0.00069 to 0.00066, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 60: val_loss improved from 0.00066 to 0.00065, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 61: val_loss did not improve from 0.00065
#
# Epoch 62: val_loss did not improve from 0.00065
#
# Epoch 63: val_loss did not improve from 0.00065
#
# Epoch 64: val_loss improved from 0.00065 to 0.00064, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 65: val_loss did not improve from 0.00064
#
# Epoch 66: val_loss improved from 0.00064 to 0.00063, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 67: val_loss improved from 0.00063 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 68: val_loss improved from 0.00062 to 0.00061, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 69: val_loss did not improve from 0.00061
#
# Epoch 70: val_loss did not improve from 0.00061
#
# Epoch 71: val_loss did not improve from 0.00061
#
# Epoch 72: val_loss did not improve from 0.00061
#
# Epoch 73: val_loss did not improve from 0.00061
#
# Epoch 74: val_loss did not improve from 0.00061
#
# Epoch 75: val_loss did not improve from 0.00061
#
# Epoch 76: val_loss improved from 0.00061 to 0.00059, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 77: val_loss improved from 0.00059 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 78: val_loss did not improve from 0.00058
#
# Epoch 79: val_loss improved from 0.00058 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 80: val_loss did not improve from 0.00058
#
# Epoch 81: val_loss did not improve from 0.00058
#
# Epoch 82: val_loss did not improve from 0.00058
#
# Epoch 83: val_loss did not improve from 0.00058
#
# Epoch 84: val_loss did not improve from 0.00058
#
# Epoch 85: val_loss improved from 0.00058 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 86: val_loss improved from 0.00056 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 87: val_loss did not improve from 0.00055
#
# Epoch 88: val_loss did not improve from 0.00055
#
# Epoch 89: val_loss improved from 0.00055 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 90: val_loss did not improve from 0.00055
#
# Epoch 91: val_loss improved from 0.00055 to 0.00054, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 92: val_loss did not improve from 0.00054
#
# Epoch 93: val_loss did not improve from 0.00054
#
# Epoch 94: val_loss did not improve from 0.00054
#
# Epoch 95: val_loss did not improve from 0.00054
#
# Epoch 96: val_loss did not improve from 0.00054
#
# Epoch 97: val_loss did not improve from 0.00054
#
# Epoch 98: val_loss did not improve from 0.00054
#
# Epoch 99: val_loss did not improve from 0.00054
#
# Epoch 100: val_loss did not improve from 0.00054
# Training for 100 epochs and 2 layers...
#
# Epoch 1: val_loss improved from inf to 0.05101, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.05101 to 0.03760, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.03760 to 0.02215, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss improved from 0.02215 to 0.00581, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 5: val_loss improved from 0.00581 to 0.00478, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 6: val_loss did not improve from 0.00478
#
# Epoch 7: val_loss improved from 0.00478 to 0.00145, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 8: val_loss did not improve from 0.00145
#
# Epoch 9: val_loss did not improve from 0.00145
#
# Epoch 10: val_loss did not improve from 0.00145
#
# Epoch 11: val_loss improved from 0.00145 to 0.00142, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 12: val_loss improved from 0.00142 to 0.00116, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 13: val_loss did not improve from 0.00116
#
# Epoch 14: val_loss improved from 0.00116 to 0.00113, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 15: val_loss did not improve from 0.00113
#
# Epoch 16: val_loss improved from 0.00113 to 0.00112, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 17: val_loss improved from 0.00112 to 0.00111, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 18: val_loss did not improve from 0.00111
#
# Epoch 19: val_loss improved from 0.00111 to 0.00111, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 20: val_loss improved from 0.00111 to 0.00106, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 21: val_loss improved from 0.00106 to 0.00105, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 22: val_loss improved from 0.00105 to 0.00103, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 23: val_loss improved from 0.00103 to 0.00101, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 24: val_loss improved from 0.00101 to 0.00100, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 25: val_loss improved from 0.00100 to 0.00099, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 26: val_loss improved from 0.00099 to 0.00098, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 27: val_loss improved from 0.00098 to 0.00097, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 28: val_loss improved from 0.00097 to 0.00097, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 29: val_loss improved from 0.00097 to 0.00097, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 30: val_loss improved from 0.00097 to 0.00095, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss did not improve from 0.00095
#
# Epoch 32: val_loss improved from 0.00095 to 0.00095, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 33: val_loss improved from 0.00095 to 0.00093, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 34: val_loss improved from 0.00093 to 0.00092, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss improved from 0.00092 to 0.00091, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 36: val_loss improved from 0.00091 to 0.00090, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 37: val_loss improved from 0.00090 to 0.00089, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 38: val_loss improved from 0.00089 to 0.00088, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 39: val_loss did not improve from 0.00088
#
# Epoch 40: val_loss did not improve from 0.00088
#
# Epoch 41: val_loss improved from 0.00088 to 0.00086, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 42: val_loss improved from 0.00086 to 0.00085, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 43: val_loss did not improve from 0.00085
#
# Epoch 44: val_loss improved from 0.00085 to 0.00083, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 45: val_loss did not improve from 0.00083
#
# Epoch 46: val_loss did not improve from 0.00083
#
# Epoch 47: val_loss improved from 0.00083 to 0.00082, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 48: val_loss improved from 0.00082 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 49: val_loss improved from 0.00081 to 0.00080, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 50: val_loss improved from 0.00080 to 0.00080, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 51: val_loss did not improve from 0.00080
#
# Epoch 52: val_loss improved from 0.00080 to 0.00078, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 53: val_loss did not improve from 0.00078
#
# Epoch 54: val_loss improved from 0.00078 to 0.00077, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 55: val_loss improved from 0.00077 to 0.00076, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 56: val_loss improved from 0.00076 to 0.00076, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 57: val_loss did not improve from 0.00076
#
# Epoch 58: val_loss improved from 0.00076 to 0.00074, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 59: val_loss did not improve from 0.00074
#
# Epoch 60: val_loss improved from 0.00074 to 0.00073, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 61: val_loss did not improve from 0.00073
#
# Epoch 62: val_loss improved from 0.00073 to 0.00073, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 63: val_loss did not improve from 0.00073
#
# Epoch 64: val_loss did not improve from 0.00073
#
# Epoch 65: val_loss improved from 0.00073 to 0.00072, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 66: val_loss improved from 0.00072 to 0.00072, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 67: val_loss did not improve from 0.00072
#
# Epoch 68: val_loss improved from 0.00072 to 0.00069, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 69: val_loss did not improve from 0.00069
#
# Epoch 70: val_loss did not improve from 0.00069
#
# Epoch 71: val_loss did not improve from 0.00069
#
# Epoch 72: val_loss improved from 0.00069 to 0.00069, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 73: val_loss improved from 0.00069 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 74: val_loss improved from 0.00068 to 0.00067, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 75: val_loss did not improve from 0.00067
#
# Epoch 76: val_loss did not improve from 0.00067
#
# Epoch 77: val_loss improved from 0.00067 to 0.00067, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 78: val_loss did not improve from 0.00067
#
# Epoch 79: val_loss did not improve from 0.00067
#
# Epoch 80: val_loss improved from 0.00067 to 0.00063, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 81: val_loss did not improve from 0.00063
#
# Epoch 82: val_loss improved from 0.00063 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 83: val_loss did not improve from 0.00062
#
# Epoch 84: val_loss improved from 0.00062 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 85: val_loss improved from 0.00062 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 86: val_loss did not improve from 0.00062
#
# Epoch 87: val_loss did not improve from 0.00062
#
# Epoch 88: val_loss did not improve from 0.00062
#
# Epoch 89: val_loss did not improve from 0.00062
#
# Epoch 90: val_loss improved from 0.00062 to 0.00061, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 91: val_loss did not improve from 0.00061
#
# Epoch 92: val_loss improved from 0.00061 to 0.00060, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 93: val_loss did not improve from 0.00060
#
# Epoch 94: val_loss did not improve from 0.00060
#
# Epoch 95: val_loss did not improve from 0.00060
#
# Epoch 96: val_loss improved from 0.00060 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 97: val_loss improved from 0.00058 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 98: val_loss did not improve from 0.00058
#
# Epoch 99: val_loss did not improve from 0.00058
#
# Epoch 100: val_loss did not improve from 0.00058
# Training for 100 epochs and 3 layers...
#
# Epoch 1: val_loss improved from inf to 0.04413, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.04413 to 0.02423, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.02423 to 0.00739, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss improved from 0.00739 to 0.00150, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 5: val_loss did not improve from 0.00150
#
# Epoch 6: val_loss did not improve from 0.00150
#
# Epoch 7: val_loss improved from 0.00150 to 0.00139, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 8: val_loss did not improve from 0.00139
#
# Epoch 9: val_loss did not improve from 0.00139
#
# Epoch 10: val_loss improved from 0.00139 to 0.00134, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 11: val_loss improved from 0.00134 to 0.00124, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 12: val_loss improved from 0.00124 to 0.00111, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 13: val_loss improved from 0.00111 to 0.00108, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 14: val_loss improved from 0.00108 to 0.00107, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 15: val_loss improved from 0.00107 to 0.00103, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 16: val_loss improved from 0.00103 to 0.00103, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 17: val_loss improved from 0.00103 to 0.00102, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 18: val_loss improved from 0.00102 to 0.00101, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 19: val_loss improved from 0.00101 to 0.00101, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 20: val_loss improved from 0.00101 to 0.00100, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 21: val_loss improved from 0.00100 to 0.00099, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 22: val_loss improved from 0.00099 to 0.00098, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 23: val_loss improved from 0.00098 to 0.00097, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 24: val_loss improved from 0.00097 to 0.00096, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 25: val_loss improved from 0.00096 to 0.00096, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 26: val_loss improved from 0.00096 to 0.00095, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 27: val_loss did not improve from 0.00095
#
# Epoch 28: val_loss improved from 0.00095 to 0.00092, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 29: val_loss did not improve from 0.00092
#
# Epoch 30: val_loss improved from 0.00092 to 0.00091, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss did not improve from 0.00091
#
# Epoch 32: val_loss improved from 0.00091 to 0.00090, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 33: val_loss did not improve from 0.00090
#
# Epoch 34: val_loss improved from 0.00090 to 0.00085, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss improved from 0.00085 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 36: val_loss improved from 0.00084 to 0.00082, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 37: val_loss improved from 0.00082 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 38: val_loss improved from 0.00081 to 0.00079, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 39: val_loss did not improve from 0.00079
#
# Epoch 40: val_loss did not improve from 0.00079
#
# Epoch 41: val_loss improved from 0.00079 to 0.00077, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 42: val_loss did not improve from 0.00077
#
# Epoch 43: val_loss improved from 0.00077 to 0.00077, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 44: val_loss improved from 0.00077 to 0.00075, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 45: val_loss did not improve from 0.00075
#
# Epoch 46: val_loss improved from 0.00075 to 0.00072, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 47: val_loss did not improve from 0.00072
#
# Epoch 48: val_loss improved from 0.00072 to 0.00071, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 49: val_loss improved from 0.00071 to 0.00070, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 50: val_loss did not improve from 0.00070
#
# Epoch 51: val_loss did not improve from 0.00070
#
# Epoch 52: val_loss improved from 0.00070 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 53: val_loss improved from 0.00068 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 54: val_loss improved from 0.00068 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 55: val_loss did not improve from 0.00068
#
# Epoch 56: val_loss improved from 0.00068 to 0.00066, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 57: val_loss improved from 0.00066 to 0.00066, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 58: val_loss did not improve from 0.00066
#
# Epoch 59: val_loss improved from 0.00066 to 0.00064, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 60: val_loss improved from 0.00064 to 0.00064, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 61: val_loss did not improve from 0.00064
#
# Epoch 62: val_loss did not improve from 0.00064
#
# Epoch 63: val_loss did not improve from 0.00064
#
# Epoch 64: val_loss improved from 0.00064 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 65: val_loss improved from 0.00062 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 66: val_loss did not improve from 0.00062
#
# Epoch 67: val_loss did not improve from 0.00062
#
# Epoch 68: val_loss improved from 0.00062 to 0.00061, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 69: val_loss improved from 0.00061 to 0.00061, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 70: val_loss improved from 0.00061 to 0.00061, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 71: val_loss did not improve from 0.00061
#
# Epoch 72: val_loss improved from 0.00061 to 0.00060, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 73: val_loss did not improve from 0.00060
#
# Epoch 74: val_loss improved from 0.00060 to 0.00059, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 75: val_loss did not improve from 0.00059
#
# Epoch 76: val_loss did not improve from 0.00059
#
# Epoch 77: val_loss improved from 0.00059 to 0.00059, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 78: val_loss did not improve from 0.00059
#
# Epoch 79: val_loss improved from 0.00059 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 80: val_loss did not improve from 0.00058
#
# Epoch 81: val_loss did not improve from 0.00058
#
# Epoch 82: val_loss improved from 0.00058 to 0.00057, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 83: val_loss improved from 0.00057 to 0.00057, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 84: val_loss did not improve from 0.00057
#
# Epoch 85: val_loss improved from 0.00057 to 0.00057, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 86: val_loss improved from 0.00057 to 0.00057, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 87: val_loss did not improve from 0.00057
#
# Epoch 88: val_loss did not improve from 0.00057
#
# Epoch 89: val_loss improved from 0.00057 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 90: val_loss improved from 0.00056 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 91: val_loss did not improve from 0.00056
#
# Epoch 92: val_loss improved from 0.00056 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 93: val_loss did not improve from 0.00055
#
# Epoch 94: val_loss did not improve from 0.00055
#
# Epoch 95: val_loss improved from 0.00055 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 96: val_loss improved from 0.00055 to 0.00054, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 97: val_loss did not improve from 0.00054
#
# Epoch 98: val_loss did not improve from 0.00054
#
# Epoch 99: val_loss improved from 0.00054 to 0.00054, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 100: val_loss did not improve from 0.00054
# Training for 150 epochs and 1 layers...
#
# Epoch 1: val_loss improved from inf to 0.02738, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.02738 to 0.00561, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.00561 to 0.00215, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss did not improve from 0.00215
#
# Epoch 5: val_loss did not improve from 0.00215
#
# Epoch 6: val_loss improved from 0.00215 to 0.00145, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 7: val_loss did not improve from 0.00145
#
# Epoch 8: val_loss did not improve from 0.00145
#
# Epoch 9: val_loss did not improve from 0.00145
#
# Epoch 10: val_loss improved from 0.00145 to 0.00125, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 11: val_loss improved from 0.00125 to 0.00121, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 12: val_loss improved from 0.00121 to 0.00118, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 13: val_loss improved from 0.00118 to 0.00106, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 14: val_loss improved from 0.00106 to 0.00103, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 15: val_loss improved from 0.00103 to 0.00102, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 16: val_loss improved from 0.00102 to 0.00101, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 17: val_loss improved from 0.00101 to 0.00098, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 18: val_loss did not improve from 0.00098
#
# Epoch 19: val_loss improved from 0.00098 to 0.00097, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 20: val_loss improved from 0.00097 to 0.00096, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 21: val_loss did not improve from 0.00096
#
# Epoch 22: val_loss improved from 0.00096 to 0.00095, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 23: val_loss improved from 0.00095 to 0.00094, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 24: val_loss improved from 0.00094 to 0.00093, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 25: val_loss improved from 0.00093 to 0.00091, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 26: val_loss improved from 0.00091 to 0.00090, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 27: val_loss improved from 0.00090 to 0.00089, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 28: val_loss did not improve from 0.00089
#
# Epoch 29: val_loss improved from 0.00089 to 0.00088, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 30: val_loss improved from 0.00088 to 0.00088, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss did not improve from 0.00088
#
# Epoch 32: val_loss improved from 0.00088 to 0.00086, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 33: val_loss improved from 0.00086 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 34: val_loss improved from 0.00084 to 0.00083, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss did not improve from 0.00083
#
# Epoch 36: val_loss improved from 0.00083 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 37: val_loss improved from 0.00081 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 38: val_loss did not improve from 0.00081
#
# Epoch 39: val_loss improved from 0.00081 to 0.00079, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 40: val_loss did not improve from 0.00079
#
# Epoch 41: val_loss did not improve from 0.00079
#
# Epoch 42: val_loss improved from 0.00079 to 0.00077, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 43: val_loss did not improve from 0.00077
#
# Epoch 44: val_loss improved from 0.00077 to 0.00075, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 45: val_loss did not improve from 0.00075
#
# Epoch 46: val_loss did not improve from 0.00075
#
# Epoch 47: val_loss improved from 0.00075 to 0.00073, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 48: val_loss did not improve from 0.00073
#
# Epoch 49: val_loss did not improve from 0.00073
#
# Epoch 50: val_loss improved from 0.00073 to 0.00070, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 51: val_loss did not improve from 0.00070
#
# Epoch 52: val_loss did not improve from 0.00070
#
# Epoch 53: val_loss did not improve from 0.00070
#
# Epoch 54: val_loss improved from 0.00070 to 0.00070, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 55: val_loss improved from 0.00070 to 0.00069, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 56: val_loss improved from 0.00069 to 0.00067, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 57: val_loss improved from 0.00067 to 0.00066, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 58: val_loss improved from 0.00066 to 0.00065, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 59: val_loss improved from 0.00065 to 0.00064, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 60: val_loss improved from 0.00064 to 0.00064, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 61: val_loss did not improve from 0.00064
#
# Epoch 62: val_loss did not improve from 0.00064
#
# Epoch 63: val_loss did not improve from 0.00064
#
# Epoch 64: val_loss improved from 0.00064 to 0.00063, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 65: val_loss did not improve from 0.00063
#
# Epoch 66: val_loss improved from 0.00063 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 67: val_loss improved from 0.00062 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 68: val_loss did not improve from 0.00062
#
# Epoch 69: val_loss did not improve from 0.00062
#
# Epoch 70: val_loss improved from 0.00062 to 0.00061, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 71: val_loss did not improve from 0.00061
#
# Epoch 72: val_loss did not improve from 0.00061
#
# Epoch 73: val_loss did not improve from 0.00061
#
# Epoch 74: val_loss did not improve from 0.00061
#
# Epoch 75: val_loss improved from 0.00061 to 0.00060, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 76: val_loss improved from 0.00060 to 0.00060, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 77: val_loss did not improve from 0.00060
#
# Epoch 78: val_loss did not improve from 0.00060
#
# Epoch 79: val_loss did not improve from 0.00060
#
# Epoch 80: val_loss improved from 0.00060 to 0.00060, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 81: val_loss improved from 0.00060 to 0.00059, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 82: val_loss improved from 0.00059 to 0.00059, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 83: val_loss did not improve from 0.00059
#
# Epoch 84: val_loss did not improve from 0.00059
#
# Epoch 85: val_loss improved from 0.00059 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 86: val_loss did not improve from 0.00058
#
# Epoch 87: val_loss did not improve from 0.00058
#
# Epoch 88: val_loss improved from 0.00058 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 89: val_loss did not improve from 0.00058
#
# Epoch 90: val_loss did not improve from 0.00058
#
# Epoch 91: val_loss improved from 0.00058 to 0.00057, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 92: val_loss did not improve from 0.00057
#
# Epoch 93: val_loss did not improve from 0.00057
#
# Epoch 94: val_loss did not improve from 0.00057
#
# Epoch 95: val_loss did not improve from 0.00057
#
# Epoch 96: val_loss did not improve from 0.00057
#
# Epoch 97: val_loss improved from 0.00057 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 98: val_loss did not improve from 0.00056
#
# Epoch 99: val_loss did not improve from 0.00056
#
# Epoch 100: val_loss improved from 0.00056 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 101: val_loss did not improve from 0.00056
#
# Epoch 102: val_loss did not improve from 0.00056
#
# Epoch 103: val_loss did not improve from 0.00056
#
# Epoch 104: val_loss improved from 0.00056 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 105: val_loss improved from 0.00056 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 106: val_loss did not improve from 0.00056
#
# Epoch 107: val_loss improved from 0.00056 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 108: val_loss did not improve from 0.00055
#
# Epoch 109: val_loss did not improve from 0.00055
#
# Epoch 110: val_loss did not improve from 0.00055
#
# Epoch 111: val_loss did not improve from 0.00055
#
# Epoch 112: val_loss improved from 0.00055 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 113: val_loss did not improve from 0.00055
#
# Epoch 114: val_loss improved from 0.00055 to 0.00054, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 115: val_loss did not improve from 0.00054
#
# Epoch 116: val_loss did not improve from 0.00054
#
# Epoch 117: val_loss did not improve from 0.00054
#
# Epoch 118: val_loss did not improve from 0.00054
#
# Epoch 119: val_loss did not improve from 0.00054
#
# Epoch 120: val_loss improved from 0.00054 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 121: val_loss did not improve from 0.00053
#
# Epoch 122: val_loss did not improve from 0.00053
#
# Epoch 123: val_loss did not improve from 0.00053
#
# Epoch 124: val_loss improved from 0.00053 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 125: val_loss improved from 0.00053 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 126: val_loss did not improve from 0.00053
#
# Epoch 127: val_loss did not improve from 0.00053
#
# Epoch 128: val_loss did not improve from 0.00053
#
# Epoch 129: val_loss did not improve from 0.00053
#
# Epoch 130: val_loss did not improve from 0.00053
#
# Epoch 131: val_loss did not improve from 0.00053
#
# Epoch 132: val_loss did not improve from 0.00053
#
# Epoch 133: val_loss did not improve from 0.00053
#
# Epoch 134: val_loss improved from 0.00053 to 0.00052, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 135: val_loss did not improve from 0.00052
#
# Epoch 136: val_loss did not improve from 0.00052
#
# Epoch 137: val_loss did not improve from 0.00052
#
# Epoch 138: val_loss did not improve from 0.00052
#
# Epoch 139: val_loss did not improve from 0.00052
#
# Epoch 140: val_loss did not improve from 0.00052
#
# Epoch 141: val_loss did not improve from 0.00052
#
# Epoch 142: val_loss improved from 0.00052 to 0.00051, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 143: val_loss did not improve from 0.00051
#
# Epoch 144: val_loss did not improve from 0.00051
#
# Epoch 145: val_loss did not improve from 0.00051
#
# Epoch 146: val_loss did not improve from 0.00051
#
# Epoch 147: val_loss did not improve from 0.00051
#
# Epoch 148: val_loss did not improve from 0.00051
#
# Epoch 149: val_loss improved from 0.00051 to 0.00051, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 150: val_loss did not improve from 0.00051
# Training for 150 epochs and 2 layers...
#
# Epoch 1: val_loss improved from inf to 0.03551, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.03551 to 0.00844, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.00844 to 0.00229, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss did not improve from 0.00229
#
# Epoch 5: val_loss improved from 0.00229 to 0.00199, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 6: val_loss improved from 0.00199 to 0.00153, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 7: val_loss did not improve from 0.00153
#
# Epoch 8: val_loss improved from 0.00153 to 0.00144, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 9: val_loss improved from 0.00144 to 0.00142, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 10: val_loss improved from 0.00142 to 0.00121, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 11: val_loss improved from 0.00121 to 0.00113, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 12: val_loss did not improve from 0.00113
#
# Epoch 13: val_loss improved from 0.00113 to 0.00107, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 14: val_loss improved from 0.00107 to 0.00107, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 15: val_loss improved from 0.00107 to 0.00106, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 16: val_loss improved from 0.00106 to 0.00106, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 17: val_loss improved from 0.00106 to 0.00103, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 18: val_loss improved from 0.00103 to 0.00102, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 19: val_loss improved from 0.00102 to 0.00100, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 20: val_loss improved from 0.00100 to 0.00099, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 21: val_loss improved from 0.00099 to 0.00098, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 22: val_loss improved from 0.00098 to 0.00096, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 23: val_loss improved from 0.00096 to 0.00095, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 24: val_loss did not improve from 0.00095
#
# Epoch 25: val_loss improved from 0.00095 to 0.00092, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 26: val_loss did not improve from 0.00092
#
# Epoch 27: val_loss improved from 0.00092 to 0.00090, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 28: val_loss improved from 0.00090 to 0.00089, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 29: val_loss improved from 0.00089 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 30: val_loss improved from 0.00087 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss improved from 0.00087 to 0.00085, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 32: val_loss did not improve from 0.00085
#
# Epoch 33: val_loss improved from 0.00085 to 0.00083, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 34: val_loss improved from 0.00083 to 0.00083, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss improved from 0.00083 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 36: val_loss improved from 0.00081 to 0.00080, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 37: val_loss did not improve from 0.00080
#
# Epoch 38: val_loss did not improve from 0.00080
#
# Epoch 39: val_loss improved from 0.00080 to 0.00078, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 40: val_loss did not improve from 0.00078
#
# Epoch 41: val_loss improved from 0.00078 to 0.00075, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 42: val_loss improved from 0.00075 to 0.00075, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 43: val_loss did not improve from 0.00075
#
# Epoch 44: val_loss did not improve from 0.00075
#
# Epoch 45: val_loss did not improve from 0.00075
#
# Epoch 46: val_loss improved from 0.00075 to 0.00072, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 47: val_loss did not improve from 0.00072
#
# Epoch 48: val_loss improved from 0.00072 to 0.00071, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 49: val_loss improved from 0.00071 to 0.00070, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 50: val_loss improved from 0.00070 to 0.00070, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 51: val_loss did not improve from 0.00070
#
# Epoch 52: val_loss improved from 0.00070 to 0.00069, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 53: val_loss did not improve from 0.00069
#
# Epoch 54: val_loss did not improve from 0.00069
#
# Epoch 55: val_loss did not improve from 0.00069
#
# Epoch 56: val_loss improved from 0.00069 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 57: val_loss improved from 0.00068 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 58: val_loss did not improve from 0.00068
#
# Epoch 59: val_loss improved from 0.00068 to 0.00066, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 60: val_loss improved from 0.00066 to 0.00065, saving model to tmp/ckeckpointer.ckpt
#
# ...
#
# Epoch 146: val_loss did not improve from 0.00053
#
# Epoch 147: val_loss did not improve from 0.00053
#
# Epoch 148: val_loss did not improve from 0.00053
#
# Epoch 149: val_loss did not improve from 0.00053
#
# Epoch 150: val_loss improved from 0.00053 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 151: val_loss did not improve from 0.00053
#
# Epoch 152: val_loss did not improve from 0.00053
#
# Epoch 153: val_loss improved from 0.00053 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 154: val_loss improved from 0.00053 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 155: val_loss improved from 0.00053 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 156: val_loss did not improve from 0.00053
#
# Epoch 157: val_loss did not improve from 0.00053
#
# Epoch 158: val_loss did not improve from 0.00053
#
# Epoch 159: val_loss did not improve from 0.00053
#
# Epoch 160: val_loss did not improve from 0.00053
#
# Epoch 161: val_loss did not improve from 0.00053
#
# Epoch 162: val_loss did not improve from 0.00053
#
# Epoch 163: val_loss did not improve from 0.00053
#
# Epoch 164: val_loss did not improve from 0.00053
#
# Epoch 165: val_loss did not improve from 0.00053
#
# Epoch 166: val_loss improved from 0.00053 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 167: val_loss did not improve from 0.00053
#
# Epoch 168: val_loss did not improve from 0.00053
#
# Epoch 169: val_loss improved from 0.00053 to 0.00052, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 170: val_loss did not improve from 0.00052
#
# Epoch 171: val_loss did not improve from 0.00052
#
# Epoch 172: val_loss did not improve from 0.00052
#
# Epoch 173: val_loss did not improve from 0.00052
#
# Epoch 174: val_loss did not improve from 0.00052
#
# Epoch 175: val_loss did not improve from 0.00052
#
# Epoch 176: val_loss did not improve from 0.00052
#
# Epoch 177: val_loss did not improve from 0.00052
#
# Epoch 178: val_loss did not improve from 0.00052
#
# Epoch 179: val_loss did not improve from 0.00052
#
# Epoch 180: val_loss did not improve from 0.00052
#
# Epoch 181: val_loss did not improve from 0.00052
#
# Epoch 182: val_loss did not improve from 0.00052
#
# Epoch 183: val_loss did not improve from 0.00052
#
# Epoch 184: val_loss did not improve from 0.00052
#
# Epoch 185: val_loss did not improve from 0.00052
#
# Epoch 186: val_loss improved from 0.00052 to 0.00052, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 187: val_loss did not improve from 0.00052
#
# Epoch 188: val_loss did not improve from 0.00052
#
# Epoch 189: val_loss did not improve from 0.00052
#
# Epoch 190: val_loss did not improve from 0.00052
#
# Epoch 191: val_loss did not improve from 0.00052
#
# Epoch 192: val_loss did not improve from 0.00052
#
# Epoch 193: val_loss did not improve from 0.00052
#
# Epoch 194: val_loss did not improve from 0.00052
#
# Epoch 195: val_loss did not improve from 0.00052
#
# Epoch 196: val_loss did not improve from 0.00052
#
# Epoch 197: val_loss did not improve from 0.00052
#
# Epoch 198: val_loss improved from 0.00052 to 0.00052, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 199: val_loss did not improve from 0.00052
#
# Epoch 200: val_loss did not improve from 0.00052
# Training for 200 epochs and 3 layers...
#
# Epoch 1: val_loss improved from inf to 0.03730, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 2: val_loss improved from 0.03730 to 0.01717, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 3: val_loss improved from 0.01717 to 0.00487, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 4: val_loss improved from 0.00487 to 0.00100, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 5: val_loss did not improve from 0.00100
#
# Epoch 6: val_loss did not improve from 0.00100
#
# Epoch 7: val_loss did not improve from 0.00100
#
# Epoch 8: val_loss did not improve from 0.00100
#
# Epoch 9: val_loss did not improve from 0.00100
#
# Epoch 10: val_loss did not improve from 0.00100
#
# Epoch 11: val_loss did not improve from 0.00100
#
# Epoch 12: val_loss did not improve from 0.00100
#
# Epoch 13: val_loss did not improve from 0.00100
#
# Epoch 14: val_loss did not improve from 0.00100
#
# Epoch 15: val_loss did not improve from 0.00100
#
# Epoch 16: val_loss did not improve from 0.00100
#
# Epoch 17: val_loss did not improve from 0.00100
#
# Epoch 18: val_loss improved from 0.00100 to 0.00098, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 19: val_loss improved from 0.00098 to 0.00097, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 20: val_loss did not improve from 0.00097
#
# Epoch 21: val_loss improved from 0.00097 to 0.00096, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 22: val_loss improved from 0.00096 to 0.00093, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 23: val_loss did not improve from 0.00093
#
# Epoch 24: val_loss improved from 0.00093 to 0.00091, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 25: val_loss improved from 0.00091 to 0.00090, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 26: val_loss improved from 0.00090 to 0.00089, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 27: val_loss improved from 0.00089 to 0.00088, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 28: val_loss improved from 0.00088 to 0.00087, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 29: val_loss did not improve from 0.00087
#
# Epoch 30: val_loss improved from 0.00087 to 0.00086, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 31: val_loss did not improve from 0.00086
#
# Epoch 32: val_loss improved from 0.00086 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 33: val_loss improved from 0.00084 to 0.00084, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 34: val_loss improved from 0.00084 to 0.00082, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 35: val_loss improved from 0.00082 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 36: val_loss did not improve from 0.00081
#
# Epoch 37: val_loss improved from 0.00081 to 0.00081, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 38: val_loss improved from 0.00081 to 0.00080, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 39: val_loss improved from 0.00080 to 0.00079, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 40: val_loss improved from 0.00079 to 0.00077, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 41: val_loss improved from 0.00077 to 0.00077, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 42: val_loss improved from 0.00077 to 0.00076, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 43: val_loss improved from 0.00076 to 0.00075, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 44: val_loss did not improve from 0.00075
#
# Epoch 45: val_loss did not improve from 0.00075
#
# Epoch 46: val_loss improved from 0.00075 to 0.00074, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 47: val_loss improved from 0.00074 to 0.00073, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 48: val_loss did not improve from 0.00073
#
# Epoch 49: val_loss did not improve from 0.00073
#
# Epoch 50: val_loss did not improve from 0.00073
#
# Epoch 51: val_loss improved from 0.00073 to 0.00071, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 52: val_loss improved from 0.00071 to 0.00070, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 53: val_loss did not improve from 0.00070
#
# Epoch 54: val_loss improved from 0.00070 to 0.00069, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 55: val_loss improved from 0.00069 to 0.00068, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 56: val_loss improved from 0.00068 to 0.00067, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 57: val_loss improved from 0.00067 to 0.00067, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 58: val_loss did not improve from 0.00067
#
# Epoch 59: val_loss did not improve from 0.00067
#
# Epoch 60: val_loss improved from 0.00067 to 0.00067, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 61: val_loss improved from 0.00067 to 0.00065, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 62: val_loss improved from 0.00065 to 0.00065, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 63: val_loss did not improve from 0.00065
#
# Epoch 64: val_loss did not improve from 0.00065
#
# Epoch 65: val_loss improved from 0.00065 to 0.00065, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 66: val_loss did not improve from 0.00065
#
# Epoch 67: val_loss did not improve from 0.00065
#
# Epoch 68: val_loss improved from 0.00065 to 0.00063, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 69: val_loss did not improve from 0.00063
#
# Epoch 70: val_loss did not improve from 0.00063
#
# Epoch 71: val_loss did not improve from 0.00063
#
# Epoch 72: val_loss did not improve from 0.00063
#
# Epoch 73: val_loss did not improve from 0.00063
#
# Epoch 74: val_loss did not improve from 0.00063
#
# Epoch 75: val_loss improved from 0.00063 to 0.00062, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 76: val_loss did not improve from 0.00062
#
# Epoch 77: val_loss improved from 0.00062 to 0.00061, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 78: val_loss did not improve from 0.00061
#
# Epoch 79: val_loss did not improve from 0.00061
#
# Epoch 80: val_loss did not improve from 0.00061
#
# Epoch 81: val_loss improved from 0.00061 to 0.00060, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 82: val_loss improved from 0.00060 to 0.00060, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 83: val_loss did not improve from 0.00060
#
# Epoch 84: val_loss did not improve from 0.00060
#
# Epoch 85: val_loss improved from 0.00060 to 0.00060, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 86: val_loss did not improve from 0.00060
#
# Epoch 87: val_loss improved from 0.00060 to 0.00059, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 88: val_loss improved from 0.00059 to 0.00059, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 89: val_loss did not improve from 0.00059
#
# Epoch 90: val_loss improved from 0.00059 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 91: val_loss improved from 0.00058 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 92: val_loss did not improve from 0.00058
#
# Epoch 93: val_loss did not improve from 0.00058
#
# Epoch 94: val_loss did not improve from 0.00058
#
# Epoch 95: val_loss improved from 0.00058 to 0.00058, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 96: val_loss did not improve from 0.00058
#
# Epoch 97: val_loss improved from 0.00058 to 0.00057, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 98: val_loss did not improve from 0.00057
#
# Epoch 99: val_loss did not improve from 0.00057
#
# Epoch 100: val_loss improved from 0.00057 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 101: val_loss did not improve from 0.00056
#
# Epoch 102: val_loss did not improve from 0.00056
#
# Epoch 103: val_loss did not improve from 0.00056
#
# Epoch 104: val_loss did not improve from 0.00056
#
# Epoch 105: val_loss did not improve from 0.00056
#
# Epoch 106: val_loss improved from 0.00056 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 107: val_loss did not improve from 0.00056
#
# Epoch 108: val_loss did not improve from 0.00056
#
# Epoch 109: val_loss did not improve from 0.00056
#
# Epoch 110: val_loss improved from 0.00056 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 111: val_loss did not improve from 0.00056
#
# Epoch 112: val_loss did not improve from 0.00056
#
# Epoch 113: val_loss improved from 0.00056 to 0.00056, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 114: val_loss improved from 0.00056 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 115: val_loss improved from 0.00055 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 116: val_loss did not improve from 0.00055
#
# Epoch 117: val_loss did not improve from 0.00055
#
# Epoch 118: val_loss improved from 0.00055 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 119: val_loss did not improve from 0.00055
#
# Epoch 120: val_loss did not improve from 0.00055
#
# Epoch 121: val_loss improved from 0.00055 to 0.00055, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 122: val_loss improved from 0.00055 to 0.00054, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 123: val_loss did not improve from 0.00054
#
# Epoch 124: val_loss did not improve from 0.00054
#
# Epoch 125: val_loss did not improve from 0.00054
#
# Epoch 126: val_loss improved from 0.00054 to 0.00054, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 127: val_loss did not improve from 0.00054
#
# Epoch 128: val_loss did not improve from 0.00054
#
# Epoch 129: val_loss did not improve from 0.00054
#
# Epoch 130: val_loss did not improve from 0.00054
#
# Epoch 131: val_loss did not improve from 0.00054
#
# Epoch 132: val_loss did not improve from 0.00054
#
# Epoch 133: val_loss did not improve from 0.00054
#
# Epoch 134: val_loss did not improve from 0.00054
#
# Epoch 135: val_loss did not improve from 0.00054
#
# Epoch 136: val_loss did not improve from 0.00054
#
# Epoch 137: val_loss improved from 0.00054 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 138: val_loss improved from 0.00053 to 0.00053, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 139: val_loss did not improve from 0.00053
#
# Epoch 140: val_loss did not improve from 0.00053
#
# Epoch 141: val_loss did not improve from 0.00053
#
# Epoch 142: val_loss did not improve from 0.00053
#
# Epoch 143: val_loss did not improve from 0.00053
#
# Epoch 144: val_loss did not improve from 0.00053
#
# Epoch 145: val_loss did not improve from 0.00053
#
# Epoch 146: val_loss improved from 0.00053 to 0.00052, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 147: val_loss did not improve from 0.00052
#
# Epoch 148: val_loss did not improve from 0.00052
#
# Epoch 149: val_loss did not improve from 0.00052
#
# Epoch 150: val_loss did not improve from 0.00052
#
# Epoch 151: val_loss improved from 0.00052 to 0.00052, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 152: val_loss did not improve from 0.00052
#
# Epoch 153: val_loss improved from 0.00052 to 0.00052, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 154: val_loss did not improve from 0.00052
#
# Epoch 155: val_loss did not improve from 0.00052
#
# Epoch 156: val_loss did not improve from 0.00052
#
# Epoch 157: val_loss did not improve from 0.00052
#
# Epoch 158: val_loss did not improve from 0.00052
#
# Epoch 159: val_loss did not improve from 0.00052
#
# Epoch 160: val_loss did not improve from 0.00052
#
# Epoch 161: val_loss improved from 0.00052 to 0.00052, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 162: val_loss did not improve from 0.00052
#
# Epoch 163: val_loss did not improve from 0.00052
#
# Epoch 164: val_loss did not improve from 0.00052
#
# Epoch 165: val_loss did not improve from 0.00052
#
# Epoch 166: val_loss did not improve from 0.00052
#
# Epoch 167: val_loss did not improve from 0.00052
#
# Epoch 168: val_loss did not improve from 0.00052
#
# Epoch 169: val_loss did not improve from 0.00052
#
# Epoch 170: val_loss did not improve from 0.00052
#
# Epoch 171: val_loss did not improve from 0.00052
#
# Epoch 172: val_loss did not improve from 0.00052
#
# Epoch 173: val_loss improved from 0.00052 to 0.00051, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 174: val_loss did not improve from 0.00051
#
# Epoch 175: val_loss did not improve from 0.00051
#
# Epoch 176: val_loss improved from 0.00051 to 0.00051, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 177: val_loss did not improve from 0.00051
#
# Epoch 178: val_loss did not improve from 0.00051
#
# Epoch 179: val_loss did not improve from 0.00051
#
# Epoch 180: val_loss did not improve from 0.00051
#
# Epoch 181: val_loss did not improve from 0.00051
#
# Epoch 182: val_loss did not improve from 0.00051
#
# Epoch 183: val_loss did not improve from 0.00051
#
# Epoch 184: val_loss did not improve from 0.00051
#
# Epoch 185: val_loss did not improve from 0.00051
#
# Epoch 186: val_loss did not improve from 0.00051
#
# Epoch 187: val_loss improved from 0.00051 to 0.00050, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 188: val_loss did not improve from 0.00050
#
# Epoch 189: val_loss did not improve from 0.00050
#
# Epoch 190: val_loss did not improve from 0.00050
#
# Epoch 191: val_loss did not improve from 0.00050
#
# Epoch 192: val_loss did not improve from 0.00050
#
# Epoch 193: val_loss did not improve from 0.00050
#
# Epoch 194: val_loss did not improve from 0.00050
#
# Epoch 195: val_loss did not improve from 0.00050
#
# Epoch 196: val_loss did not improve from 0.00050
#
# Epoch 197: val_loss did not improve from 0.00050
#
# Epoch 198: val_loss improved from 0.00050 to 0.00050, saving model to tmp/ckeckpointer.ckpt
#
# Epoch 199: val_loss did not improve from 0.00050
#
# Epoch 200: val_loss did not improve from 0.00050

# %%
# 결과 그래프로 plot
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# 학습 손실 그래프
for key, train_loss in train_loss_dict.items():
    ax1.plot(train_loss, label=f'Train - {key}')

ax1.set_ylabel('Loss')
ax1.set_title('Train Loss')
ax1.legend()

# 검증 손실 그래프
for key, val_loss in val_loss_dict.items():
    ax2.plot(val_loss, label=f'Validation - {key}')

ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.set_title('Validation Loss')
ax2.legend()

plt.tight_layout()  # 서브플롯 간 간격 조절
plt.show()
