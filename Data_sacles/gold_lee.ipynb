# %%
import pandas as pd
import numpy as np

gold_lee_data=pd.read_csv('~/Downloads/한국은행 기준금리 및 여수신금리_05160124.csv')

# %%
gold_lee_data=gold_lee_data.set_index('날짜')

# %%
gold_lee_data=gold_lee_data.transpose()

# %%
gold_lee_data.iloc[:,:]
# Out:
# 날짜          한국은행 기준금리  정부대출금금리  무역금융지원 프로그램대출금리  영세자영업자지원 프로그램대출금리  \
# 2023/05/30        3.5    3.534             2.00               2.00
# 2023/05/26        3.5    3.534             2.00               2.00
# 2023/05/25        3.5    3.534             2.00               2.00
# 2023/05/24        3.5    3.534             2.00               2.00
# 2023/05/23        3.5    3.534             2.00               2.00
# ...               ...      ...              ...                ...
# 2021/06/07        0.5    0.601             0.25               0.25
# 2021/06/04        0.5    0.601             0.25               0.25
# 2021/06/03        0.5    0.601             0.25               0.25
# 2021/06/02        0.5    0.601             0.25               0.25
# 2021/06/01        0.5    0.601             0.25               0.25
#
# 날짜          신성장·일자리지원 프로그램대출금리  설비투자지원 프로그램대출금리  지방중소기업지원 프로그램대출금리  자금조정 대출금리  \
# 2023/05/30                2.00             2.00               2.00        4.5
# ...

# %%
gold_lee_data.index
# Out:
# Index(['2023/05/30', '2023/05/26', '2023/05/25', '2023/05/24', '2023/05/23',
#        '2023/05/22', '2023/05/19', '2023/05/18', '2023/05/17', '2023/05/16',
#        ...
#        '2021/06/14', '2021/06/11', '2021/06/10', '2021/06/09', '2021/06/08',
#        '2021/06/07', '2021/06/04', '2021/06/03', '2021/06/02', '2021/06/01'],
#       dtype='object', length=496)

# %%
gold_lee_data=gold_lee_data.sort_index()

# %%
gold_lee_data.to_csv('~/Desktop/LSTM_OBJ_DEV/goldlee.csv')
