# %%
import pandas as pd

# %%
v1=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.1 (2).csv')
v1
# Out:
#      Unnamed: 0                                                 종가  \
# 0             0  [8170.0, 8170.0, 8170.0, 8170.0, 8170.0, 8170....
# 1             1  [482.9766592383384, 485.6558578982949, 485.752...
# 2             2  [10354.025721510252, 10353.579673906166, 10353...
# 3             3  [60600.0, 61536.144611040756, 64104.8588557044...
# 4             4  [21350.0, 21943.13476085663, 21930.43926954269...
# ..          ...                                                ...
# 227         227  [153094.59749857584, 153658.10745333633, 15363...
# 228         228  [2031.6868179738522, 2052.7437241896987, 2118....
# 229         229  [12157.704768180847, 13139.646089871725, 13245...
# 230         230  [34850.0, 34850.0, 34850.0, 35125.31281784177,...
# 231         231  [3560.0, 3635.1565489172935, 3635.156548917293...
#
#                gap
# 0     82369.412829
# 1      2395.132582
# 2      9355.276089
# 3      1534.906179
# 4     51657.681498
# ..             ...
# ...

# %%
v2=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.2 (1).csv')
v2
# Out:
#      Unnamed: 0                                                 종가  \
# 0             0  [211000.0, 211872.1252437681, 211728.799151256...
# 1             1  [20450.0, 20528.97521302104, 20677.0370952785,...
# 2             2  [66716.36993139982, 66731.76950563987, 66727.4...
# 3             3  [5150.0, 5155.161230107769, 5155.698828725144,...
# 4             4  [9050.0, 9079.251254101593, 9109.714156364402,...
# ..          ...                                                ...
# 227         227  [309.0, 309.0, 313.90352895259855, 330.9161904...
# 228         228  [3727.9839195311074, 3770.9076139330864, 3853....
# 229         229  [4022.777588367462, 4035.0750312084956, 4226.9...
# 230         230  [16650.0, 16650.0, 16650.0, 16650.0, 16650.0, ...
# 231         231  [3762.434238592784, 3810.3852867285414, 3935.7...
#
#               gap
# 0    2.322484e+04
# 1    1.399645e+03
# 2    1.000310e+03
# 3    3.611804e+02
# 4    3.078655e+04
# ..            ...
# 227  1.603120e+06
# ...

# %%
v3=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.3.csv')
v3
# Out:
#      Unnamed: 0                                                 종가  \
# 0           664  [5720.000000000001, 5720.000000000001, 5735.02...
# 1           665  [1924.0164615288375, 1966.4084152802827, 1980....
# 2           666  [1920.0, 1920.0, 1920.0, 1920.0, 1920.0, 1920....
# 3           667  [23759.81729984283, 23838.12861919403, 25014.3...
# 4           668  [30300.0, 30300.0, 30491.077093283337, 30767.1...
# ..          ...                                                ...
# 195         859  [4445.469784140587, 4445.723547339439, 4445.93...
# 196         860  [3220.0, 3220.0, 3220.0, 3220.0, 3220.0, 3220....
# 197         861  [1055.0, 1055.0, 1061.6810529505212, 1084.7708...
# 198         862  [9777.351636151474, 9797.969958230855, 9799.48...
# 199         863  [4195.0, 4492.466355144978, 4498.962252676487,...
#
#                gap
# 0      1467.351220
# 1      2916.095219
# 2      6918.780052
# 3       459.192585
# 4      5412.868842
# ..             ...
# ...

# %%
v4=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.4.csv')
v4
# Out:
#      Unnamed: 0                                                 종가  \
# 0           864  [806.8211834828057, 820.1654485836625, 857.289...
# 1           865  [4024.0676269928613, 4020.877503494422, 4116.4...
# 2           866  [15567.871215095125, 16356.168025881054, 16372...
# 3           867  [77100.0, 77100.0, 77130.96713244915, 77171.42...
# 4           868  [906.1458653715749, 906.2170133444171, 906.009...
# ..          ...                                                ...
# 195        1059  [2316.8132279316583, 2315.9301305198264, 2428....
# 196        1060  [1862.537059545517, 1890.357472166419, 1897.80...
# 197        1061  [4560.0, 4560.0, 4560.0, 4560.0, 4560.39858659...
# 198        1062  [519.0, 519.0, 519.0, 519.0, 519.0, 519.0, 519...
# 199        1063  [7619.999999999999, 7619.999999999999, 7649.26...
#
#               gap
# 0    5.675749e+04
# 1    5.265143e+04
# 2    1.227564e+04
# 3    5.864010e+03
# 4    3.970456e+03
# ..            ...
# 195  3.082191e+06
# ...

# %%
v5_0=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.5__.csv')
v5_0
# Out:
#     Unnamed: 0                                                 종가  \
# 0         1018  [8103.320081382991, 8103.291522368789, 8101.12...
# 1         1019  [839.9999999999999, 839.9999999999999, 839.999...
# 2         1020  [1981.0, 1981.0, 1981.0, 1981.0, 1981.0, 1981....
# 3         1021  [11250.437356829645, 11949.677646756174, 11977...
# 4         1022  [5765.240473945935, 5852.928448021412, 5873.99...
# 5         1023  [1985.0, 1985.0, 1985.0, 1985.0, 1985.0, 1999....
# 6         1024  [4615.0, 4628.879199357083, 4629.0416864305735...
# 7         1025  [1933.7592044274015, 1936.629348397255, 1937.3...
# 8         1026  [1880.0, 1880.0, 1880.0, 1907.6437580883503, 1...
# 9         1027  [1020.5044931694865, 1020.3914083167912, 1020....
# 10        1028  [2630.63722729062, 2631.8525956602143, 2690.86...
# 11        1029  [6105.088146105409, 6202.2993890196085, 6233.0...
# 12        1030  [11728.190579265354, 11725.564366430044, 11933...
# ...

# %%
v5_1=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.5.0.csv')
v5_1
# Out:
#      Unnamed: 0                                                 종가  \
# 0             0  [29600.0, 29600.0, 29600.0, 29600.0, 29600.0, ...
# 1             1  [3203.7032729014754, 3203.5109423088534, 3204....
# 2             2  [9401.08810822169, 9398.06649851799, 9399.8495...
# 3             3  [17300.0, 17832.283316850662, 18673.5256659984...
# 4             4  [10511.71181490024, 10817.660675346853, 10807....
# ..          ...                                                ...
# 97           97  [6239.291483104229, 6083.665116652846, 6107.35...
# 98           98  [5680.0, 5680.0, 5680.0, 5680.0, 5680.0, 5680....
# 99           99  [7509.999999999999, 7580.095472897093, 7663.73...
# 100         100  [2069.3206235120697, 2072.9811012626938, 2074....
# 101         101  [5371.929391384124, 5368.995788753032, 5367.25...
#
#               gap
# 0    1.459829e+04
# 1    6.275810e+04
# 2    2.352918e+04
# 3    3.433613e+04
# 4    1.568932e+04
# ..            ...
# 97   1.399988e+06
# ...

# %%
v5_2=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.5.csv')
v5_2
# Out:
#     Unnamed: 0                                                 종가  \
# 0         1064  [2105.4715494016805, 2120.8559808681407, 2123....
# 1         1065  [5321.761898895104, 5583.658987402916, 5575.79...
# 2         1066  [8346.125665783882, 8349.496574437248, 8494.96...
# 3         1067  [839.9999999999999, 912.6374602317809, 906.899...
# 4         1068  [1981.0, 2007.8881052583456, 2007.532059504837...
# ..         ...                                                ...
# 95        1159  [4191.883485913277, 4191.3391380906105, 4508.9...
# 96        1160  [1245.0, 1264.974876542886, 1297.0572239557903...
# 97        1161  [6299.999999999999, 6308.180879522115, 6305.71...
# 98        1162  [2395.0, 2461.3745287954807, 2462.176022996505...
# 99        1163  [103500.0, 103805.17139211297, 105302.47667556...
#
#              gap
# 0   1.240414e+06
# 1   7.049598e+03
# 2   3.420930e+05
# 3   1.138720e+06
# 4   1.606932e+04
# ..           ...
# 95  1.621696e+04
# 96  7.250813e+05
# ...

# %%
v6=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.6.csv')
v6
# Out:
#      Unnamed: 0                                                 종가  \
# 0          1264  [2430.0, 2430.0, 2430.0, 2430.0, 2430.0, 2430....
# 1          1265  [4094.343428552151, 4120.745334948103, 4118.33...
# 2          1266  [2722.1741611560187, 2716.0378840019307, 2720....
# 3          1267  [50800.0, 51040.70308998227, 51136.58041343093...
# 4          1268  [2915.0, 2915.0, 2915.19672720662, 2915.0, 293...
# ..          ...                                                ...
# 195        1459  [9046.178535461426, 9071.500387787819, 9224.59...
# 196        1460  [517.4228678047657, 561.2898897727331, 561.088...
# 197        1461  [5960.0, 6127.474107980728, 6193.365837007761,...
# 198        1462  [2950.0, 2950.0, 2950.0, 2950.0, 2968.14306475...
# 199        1463  [2603.995880531768, 2603.514652878046, 2603.09...
#
#                gap
# 0    353202.921242
# 1      4582.142843
# 2    140811.737874
# 3      5803.849960
# 4       966.145387
# ..             ...
# ...

# %%
v6_1=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.6.1.csv')

# %%
v7=pd.read_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/230725_v0.7.csv')
v7
# Out:
#      Unnamed: 0                                                 종가  \
# 0          2000  [94857.51878152291, 94829.57570711772, 94939.0...
# 1          2001  [42983.95438532034, 44482.317869464554, 44949....
# 2          2002  [15150.0, 15255.369037985802, 15419.5475104451...
# 3          2003  [4499.4465056757135, 4499.524665012956, 4544.7...
# 4          2004  [27700.0, 29772.80544886987, 30225.35420045257...
# ..          ...                                                ...
# 603        2603  [33948.30447653929, 34028.81023108959, 34036.7...
# 604        2604  [3175.0, 3266.46832327048, 3275.136118133863, ...
# 605        2605  [142342.80495643613, 141912.0161851247, 141753...
# 606        2606  [38441.81981831789, 43970.7811667025, 41664.10...
# 607        2607  [8200.537858344615, 8230.759423357746, 8230.38...
#
#                gap
# 0      3163.037290
# 1     37178.191317
# 2    196259.644421
# 3      2117.525521
# 4     20000.354812
# ..             ...
# ...

# %%
v5_2=v5_2[1:-1]
v5_2
# Out:
#     Unnamed: 0                                                 종가  \
# 1         1065  [5321.761898895104, 5583.658987402916, 5575.79...
# 2         1066  [8346.125665783882, 8349.496574437248, 8494.96...
# 3         1067  [839.9999999999999, 912.6374602317809, 906.899...
# 4         1068  [1981.0, 2007.8881052583456, 2007.532059504837...
# 5         1069  [10700.0, 11028.381184041502, 11486.3912653923...
# ..         ...                                                ...
# 94        1158  [18335.516703004636, 18466.786144301295, 18546...
# 95        1159  [4191.883485913277, 4191.3391380906105, 4508.9...
# 96        1160  [1245.0, 1264.974876542886, 1297.0572239557903...
# 97        1161  [6299.999999999999, 6308.180879522115, 6305.71...
# 98        1162  [2395.0, 2461.3745287954807, 2462.176022996505...
#
#              gap
# 1   7.049598e+03
# 2   3.420930e+05
# 3   1.138720e+06
# 4   1.606932e+04
# 5   1.102679e+04
# ..           ...
# 94  8.242874e+04
# 95  1.621696e+04
# ...

# %%
end_price_li=[]

# %%
v1_end=v1['종가'].iloc[:]
v2_end=v2['종가'].iloc[:]
v3_end=v3['종가'].iloc[:]
v4_end=v4['종가'].iloc[:]
v5_1_end=v5_1['종가'].iloc[:]
v5_2_end=v5_2['종가'].iloc[:]
v6=v6['종가'].iloc[:]
v6_1=v6_1['종가'].iloc[:]

v7=v7['종가'].iloc[:]

# %%
print(len(v1_end),
len(v2_end),
len(v3_end),
len(v4_end),
len(v5_1_end),
len(v5_2_end),
len(v6)
)
# Out:
# 232 232 200 200 102 98 200

# %%
def to_list__(data):
    lists=[]
    for i in data:
        lists.append(i)
    return lists

# %%
v1_end_li=to_list__(v1_end)
v2_end_li=to_list__(v2_end)
v3_end_li=to_list__(v3_end)
v4_end_li=to_list__(v4_end)
v5_1_end_li=to_list__(v5_1_end)
v5_2_end_li=to_list__(v5_2_end)
v6_end_li=to_list__(v6)
v6_1_end_li=to_list__(v6_1)
v7_end_li=to_list__(v7)

# %%
v6_1_end_li[0]
# Out:
# '[3845.0, 3925.184599896272, 3927.088745440046, 3924.559522519509, 3925.6303152739997, 3926.657344996929, 3985.934391501049, 3971.7160118122893, 4013.2333080073195, 4072.6479706938067, 3983.3851179505386, 4189.664633041248, 4204.028467898567, 4120.058535898725, 4150.414341071]'

# %%
string_data = v1_end_li[0]

# 스트링을 리스트로 변환
list_data = eval(string_data)

# %%
list_data
# Out:
# [8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0,
#  8170.0]

# %%
def str2list(strs):
    return eval(strs)

# %%
df_list=[]
for s in v1_end_li:
    df_list.append(str2list(s))
for s in v2_end_li:
    df_list.append(str2list(s))
for s in v3_end_li:
    df_list.append(str2list(s))
for s in v4_end_li:
    df_list.append(str2list(s))
for s in v5_1_end_li:
    df_list.append(str2list(s))
for s in v5_2_end_li:
    df_list.append(str2list(s))
for s in v5_2_end_li:
    df_list.append(str2list(s))
for s in v6_end_li:
    df_list.append(str2list(s))
for s in v6_1_end_li:
    df_list.append(str2list(s))
for s in v7_end_li:
    df_list.append(str2list(s))

# %%
df_list
# Out:
# [[8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0,
#   8170.0],
#  [482.9766592383384,
#   485.6558578982949,
#   485.75203057005996,
#   485.72601469606155,
#   485.8330023474991,
#   497.91538904607296,
#   515.7328837439417,
#   516.6635920330882,
#   522.8407038263977,
#   525.9374239370227,
#   539.101554069668,
#   536.4409741535783,
#   551.6774898357689,
#   556.570972982794,
#   559.1415045820177],
#  [10354.025721510252,
#   10353.579673906166,
#   10353.802254756292,
#   10354.656299233437,
#   10353.498549004395,
#   10376.473794738453,
#   10371.92233106494,
#   10490.138916552067,
#   10575.927542934814,
#   10589.223809611052,
#   10585.940942188105,
#   10595.842029074827,
#   10588.7855959932,
#   10595.581081662327,
#   10593.985591458777],
#  [60600.0,
#   61536.144611040756,
#   64104.85885570447,
#   65789.2124608159,
#   65887.44075069825,
# ...

# %%
len(df_list)
# Out:
# 2098

# %%
out_csv=pd.DataFrame({'종가':df_list})

# %%
out_csv
# Out:
#                                                      종가
# 0     [8170.0, 8170.0, 8170.0, 8170.0, 8170.0, 8170....
# 1     [482.9766592383384, 485.6558578982949, 485.752...
# 2     [10354.025721510252, 10353.579673906166, 10353...
# 3     [60600.0, 61536.144611040756, 64104.8588557044...
# 4     [21350.0, 21943.13476085663, 21930.43926954269...
# ...                                                 ...
# 2093  [33948.30447653929, 34028.81023108959, 34036.7...
# 2094  [3175.0, 3266.46832327048, 3275.136118133863, ...
# 2095  [142342.80495643613, 141912.0161851247, 141753...
# 2096  [38441.81981831789, 43970.7811667025, 41664.10...
# 2097  [8200.537858344615, 8230.759423357746, 8230.38...
#
# [2098 rows x 1 columns]

# %%
out_csv.to_csv('/home/junseo/Desktop/2023_1st_vacation/KRX_py/csvs/res_final.csv')
